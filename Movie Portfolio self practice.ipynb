# %%
# First let's import the packages we will use in this project
# You can do this all now or as you need them
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None


#Now we need to read in the data
df = pd.read_csv(r'D:\python\Python Project\Alex movie project\book1.csv')

# %%
df
# Out:
#                                               name rating      genre  year
# 0                                      The Shining      R      Drama  1980  \
# 1                                  The Blue Lagoon      R  Adventure  1980
# 2   Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                        Airplane!     PG     Comedy  1980
# 4                                       Caddyshack      R     Comedy  1980
# 5                                  Friday the 13th      R     Horror  1980
# 6                               The Blues Brothers      R     Action  1980
# 7                                      Raging Bull      R  Biography  1980
# 8                                      Superman II     PG     Action  1980
# 9                                  The Long Riders      R  Biography  1980
# 10                           Any Which Way You Can     PG     Action  1980
# ...

# %%
for col in df.columns:
    missing_value = np.mean(df[col].isnull())
    print('{} - {}%'. format(col,missing_value*100))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
gross1 = np.mean(df_1['gross'].isnull())
print(gross1)
# Out:
# 0.0

# %%
# We need to see if we have any missing data
# Let's loop through the data and see if there is anything missing

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    #print(format(col), round(pct_missing*100))
   
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
sns.regplot(x="gross", y="budget", data=df_2)
plt.show()

# %%
df['released'] = df['released'].astype(str)
print(df['released'].dtype)
# Out:
# object

# %%
df['released'] = df['released'].str.split("(").str[0]
df.head()
# Out:
#                                              name rating      genre  year
# 0                                     The Shining      R      Drama  1980  \
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#          released  score    votes         director                   writer
# 0  June 13, 1980     8.4   927000  Stanley Kubrick             Stephen King  \
# 1   July 2, 1980     5.8    65000   Randal Kleiser  Henry De Vere Stacpoole
# 2  June 20, 1980     8.7  1200000   Irvin Kershner           Leigh Brackett
# 3   July 2, 1980     7.7   221000     Jim Abrahams             Jim Abrahams
# 4  July 25, 1980     7.3   108000     Harold Ramis       Brian Doyle-Murray
#
# ...

# %%
df['released'] = pd.to_datetime(df['released']).dt.date
df.head()
# Out:
#                                              name rating      genre  year
# 0                                     The Shining      R      Drama  1980  \
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#      released  score    votes         director                   writer
# 0  1980-06-13    8.4   927000  Stanley Kubrick             Stephen King  \
# 1  1980-07-02    5.8    65000   Randal Kleiser  Henry De Vere Stacpoole
# 2  1980-06-20    8.7  1200000   Irvin Kershner           Leigh Brackett
# 3  1980-07-02    7.7   221000     Jim Abrahams             Jim Abrahams
# 4  1980-07-25    7.3   108000     Harold Ramis       Brian Doyle-Murray
#
#              star         country    budget      gross             company
# ...

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes         int64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime       int64
# dtype: object

# %%
df['released_1'] = df['released'].astype(str)
df = df.drop('release_1', axis =1)
df.dtypes
# Out:
# name           object
# rating         object
# genre          object
# year            int64
# released       object
# score         float64
# votes           int64
# director       object
# writer         object
# star           object
# country        object
# budget          int64
# gross           int64
# company        object
# runtime         int64
# released_1     object
# dtype: object

# %%
df['c_year'] = df['released_1'].str[:4]
df['year'] = df['c_year']
df.head()
# Out:
#                                              name rating      genre
# 0                                     The Shining      R      Drama  \
# 1                                 The Blue Lagoon      R  Adventure
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action
# 3                                       Airplane!     PG     Comedy
# 4                                      Caddyshack      R     Comedy
#
#      released  score    votes         director                   writer
# 0  1980-06-13    8.4   927000  Stanley Kubrick             Stephen King  \
# 1  1980-07-02    5.8    65000   Randal Kleiser  Henry De Vere Stacpoole
# 2  1980-06-20    8.7  1200000   Irvin Kershner           Leigh Brackett
# 3  1980-07-02    7.7   221000     Jim Abrahams             Jim Abrahams
# 4  1980-07-25    7.3   108000     Harold Ramis       Brian Doyle-Murray
#
#              star         country    budget      gross             company
# ...

# %%
df = df.drop('c_year', axis=1)
df.head()
# Out:
#                                              name rating      genre
# 0                                     The Shining      R      Drama  \
# 1                                 The Blue Lagoon      R  Adventure
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action
# 3                                       Airplane!     PG     Comedy
# 4                                      Caddyshack      R     Comedy
#
#      released  score    votes         director                   writer
# 0  1980-06-13    8.4   927000  Stanley Kubrick             Stephen King  \
# 1  1980-07-02    5.8    65000   Randal Kleiser  Henry De Vere Stacpoole
# 2  1980-06-20    8.7  1200000   Irvin Kershner           Leigh Brackett
# 3  1980-07-02    7.7   221000     Jim Abrahams             Jim Abrahams
# 4  1980-07-25    7.3   108000     Harold Ramis       Brian Doyle-Murray
#
#              star         country    budget      gross             company
# ...

# %%
df.dtypes
# Out:
# name           object
# rating         object
# genre          object
# released       object
# score         float64
# votes           int64
# director       object
# writer         object
# star           object
# country        object
# budget          int64
# gross           int64
# company        object
# runtime         int64
# released_1     object
# year           object
# dtype: object

# %%
#numeric_columns = df.select_dtypes(include=np.number)
df_num = df.select_dtypes(include=np.number)
df_num.corr()
# Out:
#             score     votes    budget     gross   runtime
# score    1.000000  0.677971  0.084823  0.415743  0.437528
# votes    0.677971  1.000000  0.198403  0.735373  0.520543
# budget   0.084823  0.198403  1.000000  0.249961  0.652465
# gross    0.415743  0.735373  0.249961  1.000000  0.269386
# runtime  0.437528  0.520543  0.652465  0.269386  1.000000

# %%
# Correlation Matrix between all numeric columns

df_p = df_num.corr(method ='pearson')
sns.heatmap(df_p, annot=True)
#plt.show()
# Out:
# <Axes: >

# %%
# !pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df_k = df_num.corr(method ='kendall')
sns.heatmap(df_k,annot=True)
plt.show()

# %%
df_s = df_num.corr(method ='spearman')
sns.heatmap(df_s, annot=True)
plt.show()

# %%
correlation_matrix = df_num.corr()

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Numeric Features")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
#To convert non-numeric to numeric
df_allnum = df
for col in df_allnum.columns:
    if (df_allnum[col].dtype == 'object'):
        df_allnum[col] = df_allnum[col].astype('category')
        df_allnum[col] = df_allnum[col].cat.codes

df_allnum.head()
# Out:
#    name  rating  genre  released  score    votes  director  writer  star
# 0    17       1      5         3    8.4   927000        16      16     9  \
# 1    12       1      1         5    5.8    65000        11       4     2
# 2    10       0      0         4    8.7  1200000         4      12    12
# 3     1       0      3         5    7.7   221000         7       8    16
# 4     3       1      3         6    7.3   108000         3       2     3
#
#    country    budget      gross  company  runtime  released_1  year
# 0        1  19000000   46998772       14      146           3     0
# 1        2   4500000   58853106        3      104           5     0
# 2        2  18000000  538375067        7      124           4     0
# 3        2   3500000   83453539        9       88           5     0
# 4        2   6000000   39846344        8       98           6     0

# %%
df_p = df_allnum.corr()
sns.heatmap(df_p, annot=True)
plt.title('All correlation')
plt.xlabel('Movie feature -X')
plt.ylabel('Movie feature -Y')
plt.show()

# %%
df_allnum.corr()
# Out:
#                 name    rating     genre  released     score     votes
# name        1.000000  0.280148 -0.079591 -0.270902  0.202599  0.277189  \
# rating      0.280148  1.000000  0.422949 -0.592349  0.149047 -0.030664
# genre      -0.079591  0.422949  1.000000 -0.469309  0.086397 -0.096439
# released   -0.270902 -0.592349 -0.469309  1.000000 -0.122244 -0.260081
# score       0.202599  0.149047  0.086397 -0.122244  1.000000  0.677971
# votes       0.277189 -0.030664 -0.096439 -0.260081  0.677971  1.000000
# director    0.523220  0.387897  0.192560 -0.350329 -0.048179  0.070224
# writer     -0.190918 -0.387897  0.310663 -0.001418 -0.054356  0.296275
# star       -0.118679 -0.387897 -0.408226  0.455286  0.285368  0.230261
# country    -0.460453  0.149071  0.044401 -0.279623 -0.200822 -0.152392
# budget      0.215618 -0.259592 -0.577646  0.376550  0.084823  0.198403
# gross      -0.004649 -0.341949 -0.419087 -0.089633  0.415743  0.735373
# ...

# %%
corr_mat = df_allnum.corr()
corr_pair = corr_mat.unstack()
corr_pair
# Out:
# name  name          1.000000
#       rating        0.280148
#       genre        -0.079591
#       released     -0.270902
#       score         0.202599
#                       ...
# year  gross        -0.069350
#       company      -0.442909
#       runtime       0.068862
#       released_1    0.544530
#       year          1.000000
# Length: 256, dtype: float64

# %%
sort_df_allnum = corr_pair.sort_values()
sort_df_allnum
# Out:
# year      country      -0.777778
# country   year         -0.777778
# released  rating       -0.592349
# rating    released_1   -0.592349
#           released     -0.592349
#                           ...
# gross     gross         1.000000
# company   company       1.000000
# runtime   runtime       1.000000
# writer    writer        1.000000
# year      year          1.000000
# Length: 256, dtype: float64

# %%
high_corr = sort_df_allnum[(sort_df_allnum) > .5]
high_corr
# Out:
# runtime     votes         0.520543
# votes       runtime       0.520543
# director    name          0.523220
# name        director      0.523220
# year        released_1    0.544530
# released_1  year          0.544530
# year        released      0.544530
# released    year          0.544530
# runtime     budget        0.652465
# budget      runtime       0.652465
# votes       score         0.677971
# score       votes         0.677971
# votes       gross         0.735373
# gross       votes         0.735373
# name        name          1.000000
# released_1  released      1.000000
# rating      rating        1.000000
# genre       genre         1.000000
# released    released      1.000000
#             released_1    1.000000
# score       score         1.000000
# votes       votes         1.000000
# released_1  released_1    1.000000
# director    director      1.000000
# star        star          1.000000
# country     country       1.000000
# budget      budget        1.000000
# ...

# %%
# votes and score have high corellation with gross
##################################################

# %%
# Using factorize - this assigns a random numeric value for each unique categorical value

df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
#                      budget   company   country  director     genre     gross  \
# budget             1.000000  0.070302 -0.189282  0.480919  0.300018  0.978268
# company            0.070302  1.000000  0.061540  0.155935  0.060236  0.101625
# country           -0.189282  0.061540  1.000000 -0.133631 -0.013013 -0.187801
# director           0.480919  0.155935 -0.133631  1.000000  0.216499  0.507853
# genre              0.300018  0.060236 -0.013013  0.216499  1.000000  0.292627
# gross              0.978268  0.101625 -0.187801  0.507853  0.292627  1.000000
# name               0.965431  0.101876 -0.187762  0.504802  0.288330  0.984267
# rating            -0.062005  0.000846  0.124684 -0.028938 -0.024621 -0.064561
# released           0.370211  0.166275 -0.051932  0.292789  0.097809  0.422125
# runtime            0.134315 -0.027840  0.021056  0.044193  0.031636  0.135257
# score              0.009605  0.031371  0.012047  0.036790  0.041309  0.013615
# ...

# %%
correlation_matrix = df.apply(lambda x: x.factorize()[0]).corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
correlation_mat = df.apply(lambda x: x.factorize()[0]).corr()

corr_pairs = correlation_mat.unstack()

print(corr_pairs)
# Out:
# budget  budget      1.000000
#         company     0.070302
#         country    -0.189282
#         director    0.480919
#         genre       0.300018
#                       ...
# year    score       0.010438
#         star        0.055951
#         votes      -0.025407
#         writer      0.003199
#         year        1.000000
# Length: 225, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)
# Out:
# country   budget     -0.189282
# budget    country    -0.189282
# country   gross      -0.187801
# gross     country    -0.187801
# country   name       -0.187762
#                         ...
# director  director    1.000000
# country   country     1.000000
# company   company     1.000000
# writer    writer      1.000000
# year      year        1.000000
# Length: 225, dtype: float64

# %%
# We can now take a look at the ones that have a high correlation (> 0.5)

strong_pairs = sorted_pairs[abs(sorted_pairs) > 0.5]

print(strong_pairs)
# Out:
# director  name        0.504802
# name      director    0.504802
# gross     director    0.507853
# director  gross       0.507853
# budget    writer      0.674068
# writer    budget      0.674068
#           votes       0.677493
# votes     writer      0.677493
# name      writer      0.695995
# writer    name        0.695995
# gross     writer      0.700464
# writer    gross       0.700464
# budget    votes       0.955916
# votes     budget      0.955916
# name      votes       0.960618
# votes     name        0.960618
# budget    name        0.965431
# name      budget      0.965431
# votes     gross       0.974594
# gross     votes       0.974594
# budget    gross       0.978268
# gross     budget      0.978268
#           name        0.984267
# name      gross       0.984267
# budget    budget      1.000000
# rating    rating      1.000000
# votes     votes       1.000000
# star      star        1.000000
# score     score       1.000000
# runtime   runtime     1.000000
# ...

# %%
# Looking at the top 15 compaies by gross revenue

CompanyGrossSum = df.groupby('company')[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values('gross', ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company
# Warner Bros.                              21322318408
# Universal Pictures                        19430051320
# Paramount Pictures                        17115702495
# Twentieth Century Fox Film Corporation    14788570587
# Walt Disney Pictures                      10455507123
# Columbia Pictures                          8824216545
# New Line Cinema                            8540112287
# Columbia Pictures Corporation              7720114061
# Touchstone Pictures                        6688156475
# DreamWorks                                 5458121021
# DreamWorks Animation                       4143974397
# Metro-Goldwyn-Mayer (MGM)                  3384812932
# Pixar Animation Studios                    3242024778
# Fox 2000 Pictures                          3113861473
# TriStar Pictures                           2967117827
# Name: gross, dtype: int64

# %%
df['Year'] = df['released'].astype(str).str[:4]
df
# Out:
#            budget                                 company      country  \
# 6819          0.0               Les Productions du Tr�sor       France
# 1871          0.0                      Paramount Pictures          USA
# 1852          0.0  Twentieth Century Fox Film Corporation          USA
# 1854          0.0                Morgan Creek Productions          USA
# 1855          0.0                        Renn Productions       France
# ...           ...                                     ...          ...
# 6398  250000000.0                          Marvel Studios          USA
# 6194  250000000.0                         New Line Cinema  New Zealand
# 4637  258000000.0                       Columbia Pictures          USA
# 5293  260000000.0           Walt Disney Animation Studios          USA
# 4631  300000000.0                    Walt Disney Pictures          USA
#
#               director      genre        gross  \
# 6819     Nicole Garcia      Drama      37757.0
# ...

# %%
df.groupby(['company', 'year'])[["gross"]].sum()
# Out:
#                                            gross
# company                         year
# "DIA" Productions GmbH & Co. KG 2003  26183197.0
# 1+2 Seisaku Iinkai              2000   1136776.0
# 101st Street Films              1998    306715.0
# 10th Hole Productions           2010    103280.0
# 120 Films                       2002    753501.0
# ...                                          ...
# Zucker Brothers Productions     1998   6940185.0
# double A Films                  2000   1568749.0
# erbp                            2013    444098.0
# i5 Films                        2001   8821782.0
# micro_scope                     2010   6857096.0
#
# [4056 rows x 1 columns]

# %%
CompanyGrossSum = df.groupby(['company', 'year'])[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values(['gross','company','year'], ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company                                 year
# Paramount Pictures                      2011    1486604229
# Universal Pictures                      2015    1411831667
# Warner Bros.                            2008    1327598616
#                                         2010    1255477478
#                                         2011    1217527619
#                                         2005    1175793638
# Twentieth Century Fox Film Corporation  2009    1173191407
# Warner Bros.                            2006    1154792759
#                                         2009    1146640373
# Walt Disney Pictures                    2010    1134883375
# Columbia Pictures                       2011    1072753462
# Universal Pictures                      2013    1066421491
# Warner Bros.                            2014    1062468828
# Universal Pictures                      2007    1057955786
# Columbia Pictures                       2012    1020616938
# Name: gross, dtype: int64

# %%
CompanyGrossSum = df.groupby(['company'])[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values(['gross','company'], ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company
# Warner Bros.                              21322318408
# Universal Pictures                        19430051320
# Paramount Pictures                        17115702495
# Twentieth Century Fox Film Corporation    14788570587
# Walt Disney Pictures                      10455507123
# Columbia Pictures                          8824216545
# New Line Cinema                            8540112287
# Columbia Pictures Corporation              7720114061
# Touchstone Pictures                        6688156475
# DreamWorks                                 5458121021
# DreamWorks Animation                       4143974397
# Metro-Goldwyn-Mayer (MGM)                  3384812932
# Pixar Animation Studios                    3242024778
# Fox 2000 Pictures                          3113861473
# TriStar Pictures                           2967117827
# Name: gross, dtype: int64

# %%
plt.scatter(x=df['budget'], y=df['gross'], alpha=0.5)
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')
plt.show()

# %%
df
# Out:
#            budget  company  country  director  genre        gross  name  \
# 6819          0.0     1393       16      1918      6      37757.0  1971
# 1871          0.0     1680       54      2145      4   18137661.0  3332
# 1852          0.0     2062       54      1564      7   17193886.0  3346
# 1854          0.0     1544       54       645      4    1596700.0  1031
# 1855          0.0     1811       16      1968      3    2017346.0  4026
# ...           ...      ...      ...       ...    ...          ...   ...
# 6398  250000000.0     1491       54      1412      0  459005868.0   502
# 6194  250000000.0     1582       34      2045      1  255119788.0  5420
# 4637  258000000.0      664       54      2317      0  336530303.0  4632
# 5293  260000000.0     2119       54      1882      2  200821936.0  4877
# 4631  300000000.0     2122       54       914      0  309420425.0  3890
#
#       rating  released  runtime  score  star   votes  writer  year  \
# ...

# %%
df_numerized = df


for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name]= df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized
# Out:
#            budget  company  country  director  genre        gross  name  \
# 6819          0.0     1393       16      1918      6      37757.0  1971
# 1871          0.0     1680       54      2145      4   18137661.0  3332
# 1852          0.0     2062       54      1564      7   17193886.0  3346
# 1854          0.0     1544       54       645      4    1596700.0  1031
# 1855          0.0     1811       16      1968      3    2017346.0  4026
# ...           ...      ...      ...       ...    ...          ...   ...
# 6398  250000000.0     1491       54      1412      0  459005868.0   502
# 6194  250000000.0     1582       34      2045      1  255119788.0  5420
# 4637  258000000.0      664       54      2317      0  336530303.0  4632
# 5293  260000000.0     2119       54      1882      2  200821936.0  4877
# 4631  300000000.0     2122       54       914      0  309420425.0  3890
#
#       rating  released  runtime  score  star   votes  writer  year  \
# ...

# %%
df_numerized.corr(method='pearson')
# Out:
#                      budget   company   country  director     genre     gross  \
# budget             1.000000  0.187205  0.137635  0.011602 -0.346794  0.712196
# company            0.187205  1.000000  0.107950  0.004320 -0.068330  0.187220
# country            0.137635  0.107950  1.000000  0.003699 -0.042793  0.149988
# director           0.011602  0.004320  0.003699  1.000000 -0.027669 -0.011429
# genre             -0.346794 -0.068330 -0.042793 -0.027669  1.000000 -0.242676
# gross              0.712196  0.187220  0.149988 -0.011429 -0.242676  1.000000
# name               0.028712  0.018098  0.025020  0.001906  0.018062  0.022768
# rating            -0.119660 -0.062250  0.057979  0.021926  0.100960 -0.135538
# released           0.276635  0.027898 -0.062609  0.001440 -0.039179  0.178564
# runtime            0.268226  0.033058 -0.081796  0.026779 -0.041357  0.224579
# score              0.042145 -0.010426 -0.174414  0.017130  0.056234  0.165693
# ...

# %%
correlation_matrix = df_numerized.corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
for col_name in df.columns:
    if(df[col_name].dtype == 'object'):
        df[col_name]= df[col_name].astype('category')
        df[col_name] = df[col_name].cat.codes

# %%
# Out:
#            budget  company  country  director  genre        gross  name  \
# 6819          0.0     1393       16      1918      6      37757.0  1971
# 1871          0.0     1680       54      2145      4   18137661.0  3332
# 1852          0.0     2062       54      1564      7   17193886.0  3346
# 1854          0.0     1544       54       645      4    1596700.0  1031
# 1855          0.0     1811       16      1968      3    2017346.0  4026
# ...           ...      ...      ...       ...    ...          ...   ...
# 6398  250000000.0     1491       54      1412      0  459005868.0   502
# 6194  250000000.0     1582       34      2045      1  255119788.0  5420
# 4637  258000000.0      664       54      2317      0  336530303.0  4632
# 5293  260000000.0     2119       54      1882      2  200821936.0  4877
# 4631  300000000.0     2122       54       914      0  309420425.0  3890
#
#       rating  released  runtime  score  star   votes  writer  year  \
# ...

# %%
df[cat_columns] = df[cat_columns].apply(lambda x: x.cat.codes)

df
# Out:
#            budget                                 company      country  \
# 6819          0.0               Les Productions du Tr�sor       France
# 1871          0.0                      Paramount Pictures          USA
# 1852          0.0  Twentieth Century Fox Film Corporation          USA
# 1854          0.0                Morgan Creek Productions          USA
# 1855          0.0                        Renn Productions       France
# ...           ...                                     ...          ...
# 6398  250000000.0                          Marvel Studios          USA
# 6194  250000000.0                         New Line Cinema  New Zealand
# 4637  258000000.0                       Columbia Pictures          USA
# 5293  260000000.0           Walt Disney Animation Studios          USA
# 4631  300000000.0                    Walt Disney Pictures          USA
#
#               director      genre        gross  \
# 6819     Nicole Garcia      Drama      37757.0
# ...

# %%
sns.swarmplot(x="rating", y="gross", data=df)
# Out:
# C:\Users\alexf\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 95.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\alexf\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 88.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\alexf\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 81.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\alexf\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 40.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.stripplot(x="rating", y="gross", data=df)
# Out:
# <AxesSubplot:xlabel='rating', ylabel='gross'>
