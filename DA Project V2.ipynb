# %%
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) # Adjust the configuration of plots we will create

df = pd.read_csv(r'D:\My tool\DA All tools\Python Project Data Analyst\Alex movie project\movies.csv')

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime
# 0   46998772.0        Warner Bros.    146.0
# 1   58853106.0   Columbia Pictures    104.0
# 2  538375067.0           Lucasfilm    124.0
# 3   83453539.0  Paramount Pictures     88.0
# 4   39846344.0      Orion Pictures     98.0

# %%
#Check missing data
for col in df.columns:
    data_missing = np.mean(df[col].isnull()) #
    print('{} - {}%'.format(col, data_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
#number of row and column
df.shape
# Out:
# (7668, 15)

# %%
#number of null values per column
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
#delete null values
df = df.dropna()
df.shape
#Data type check
#df.dtypes
# Out:
# (5421, 15)

# %%
#number of null values per column
df.isnull().sum()
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
#change data type of columns
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
df.head(3)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# 2           Leigh Brackett     Mark Hamill   United States  18000000
#
#        gross            company  runtime
# 0   46998772       Warner Bros.    146.0
# 1   58853106  Columbia Pictures    104.0
# 2  538375067          Lucasfilm    124.0

# %%
#Year correction:
#df['correct_year'] = df['released'].astype('str').str[:4]
df['correct_year'] = df['released'].str.extract(r'(\d{4})') # r'(\d{4})' extract a four-digit sequence(r=raw data)
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# 2           Leigh Brackett     Mark Hamill   United States  18000000
# 3             Jim Abrahams     Robert Hays   United States   3500000
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000
#
#        gross             company  runtime correct_year
# 0   46998772        Warner Bros.    146.0         1980
# 1   58853106   Columbia Pictures    104.0         1980
# 2  538375067           Lucasfilm    124.0         1980
# 3   83453539  Paramount Pictures     88.0         1980
# 4   39846344      Orion Pictures     98.0         1980

# %%
# rename column name
df = df.rename(columns={'name':'movie_name'})
df.head(2)
# Out:
#         movie_name rating      genre  year                       released  \
# 0      The Shining      R      Drama  1980  June 13, 1980 (United States)
# 1  The Blue Lagoon      R  Adventure  1980   July 2, 1980 (United States)
#
#    score     votes         director                   writer            star  \
# 0    8.4  927000.0  Stanley Kubrick             Stephen King  Jack Nicholson
# 1    5.8   65000.0   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields
#
#           country    budget     gross            company  runtime correct_year
# 0  United Kingdom  19000000  46998772       Warner Bros.    146.0         1980
# 1   United States   4500000  58853106  Columbia Pictures    104.0         1980

# %%
df_check = df.sort_values(by=['gross'],inplace=False,ascending=False) #inplace=False (default): Does not modify the original DataFrame. 
df_check.head()
# Out:
#                                       movie_name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000
# 3045       James Cameron  Leonardo DiCaprio  United States  200000000
# 6663     Lawrence Kasdan       Daisy Ridley  United States  245000000
# 7244  Christopher Markus  Robert Downey Jr.  United States  321000000
#
#            gross                company  runtime correct_year
# 5445  2847246203  Twentieth Century Fox    162.0         2009
# 7445  2797501328         Marvel Studios    181.0         2019
# 3045  2201647264  Twentieth Century Fox    194.0         1997
# 6663  2069521700              Lucasfilm    138.0         2015
# 7244  2048359754         Marvel Studios    149.0         2018

# %%
pd.set_option('display.max_rows', None) #to make visible all row with scroll

# %%
#Drop duplicate
#df['name'] = df['name'].drop_duplicates().sort_values(ascending=False)

# %%
df.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  5421.000000  5421.000000  5.421000e+03  5.421000e+03  5.421000e+03
# mean   2001.661317     6.392455  1.150661e+05  3.600917e+07  1.032297e+08
# std      10.540908     0.962730  1.844073e+05  4.157337e+07  1.873027e+08
# min    1980.000000     1.900000  1.950000e+02  6.000000e+03  3.090000e+02
# 25%    1993.000000     5.800000  1.900000e+04  1.000000e+07  1.073640e+07
# 50%    2002.000000     6.500000  5.200000e+04  2.180000e+07  3.686941e+07
# 75%    2011.000000     7.100000  1.290000e+05  4.500000e+07  1.124625e+08
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  5421.000000
# mean    108.152739
# std      18.115698
# min      63.000000
# 25%      95.000000
# 50%     105.000000
# 75%     118.000000
# max     271.000000

# %%
df.columns
# Out:
# Index(['movie_name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime', 'correct_year'],
#       dtype='object')

# %%
sns.countplot(x='genre', data = df)
# Out:
# <Axes: xlabel='genre', ylabel='count'>

# %%
#add count on the bar
plot = sns.countplot(x='genre', data = df)

for bar in plot.containers:
    plot.bar_label(bar)

# %%
#commnet: Comedy genre has the highest amount of count

# %%
#add the new column popularity based on the score column:
df['popularity'] = df['score'].apply(lambda x: 'H' if x > 6 else 'L')
df.head()
# Out:
#                                        movie_name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# 2           Leigh Brackett     Mark Hamill   United States  18000000
# 3             Jim Abrahams     Robert Hays   United States   3500000
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000
#
#        gross             company  runtime correct_year popularity
# 0   46998772        Warner Bros.    146.0         1980          H
# 1   58853106   Columbia Pictures    104.0         1980          L
# 2  538375067           Lucasfilm    124.0         1980          H
# 3   83453539  Paramount Pictures     88.0         1980          H
# 4   39846344      Orion Pictures     98.0         1980          H

# %%
# genre count with popularity
bars = sns.countplot(data = df, x = 'genre', hue='popularity')

for bar in bars.containers:
    bars.bar_label(bar)

# %%
#using groupby
genre_gross = df.groupby(['genre'], as_index = False)['gross'].sum().sort_values(by='gross', ascending=False).head(5)
sns.set(rc={'figure.figsize':(8,4)})
sns.barplot(x = 'genre', y = 'gross', data = genre_gross)
# Out:
# <Axes: xlabel='genre', ylabel='gross'>

# %%
# Scatter plot (budget vs gross)
plt.scatter(x=df['budget'], y = df['gross'])
plt.title('Budget vs Gross')
plt.xlabel('Bugdet')
plt.ylabel('Gross Earning')

plt.show()

# %%
#Plot with seaborn
sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color":"red"}, line_kws={"color":"blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
#co-relation among numeric columns
df_num = df.select_dtypes(include=['number'])
df_num.corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
df_num.corr(method='spearman')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.057741  0.427623  0.312886  0.351045  0.095444
# score    0.057741  1.000000  0.495409 -0.009971  0.183192  0.412155
# votes    0.427623  0.495409  1.000000  0.493461  0.745793  0.300621
# budget   0.312886 -0.009971  0.493461  1.000000  0.692958  0.330794
# gross    0.351045  0.183192  0.745793  0.692958  1.000000  0.257400
# runtime  0.095444  0.412155  0.300621  0.330794  0.257400  1.000000

# %%
df_num.corr(method='pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
df_num.corr(method='kendall')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.039389  0.296512  0.220833  0.239539  0.064824
# score    0.039389  1.000000  0.350185 -0.006406  0.124943  0.292254
# votes    0.296512  0.350185  1.000000  0.346274  0.553625  0.205344
# budget   0.220833 -0.006406  0.346274  1.000000  0.512057  0.231278
# gross    0.239539  0.124943  0.553625  0.512057  1.000000  0.176979
# runtime  0.064824  0.292254  0.205344  0.231278  0.176979  1.000000

# %%
correlation_matrix = df_num.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)  #annot=True: This parameter adds the numerical values to the heatmap cells
plt.title('Correlation Matrix')
plt.xlabel('Movie features')
plt.ylabel('Movie features')
plt.show()

# %%
df.dtypes
# Out:
# movie_name       object
# rating           object
# genre            object
# year              int64
# released         object
# score           float64
# votes           float64
# director         object
# writer           object
# star             object
# country          object
# budget            int64
# gross             int64
# company          object
# runtime         float64
# correct_year     object
# popularity       object
# dtype: object

# %%
all_numerized = df

for col in all_numerized.columns:
    if all_numerized[col].dtype == 'object':
        all_numerized[col] = all_numerized[col].astype('category')
        all_numerized[col] = all_numerized[col].cat.codes

all_numerized.head()
# Out:
#    movie_name  rating  genre  year  released  score      votes  director  \
# 0        4692       6      6  1980      1304    8.4   927000.0      1795
# 1        3929       6      1  1980      1127    5.8    65000.0      1578
# 2        3641       4      0  1980      1359    8.7  1200000.0       757
# 3         204       4      4  1980      1127    7.7   221000.0       889
# 4         732       6      4  1980      1170    7.3   108000.0       719
#
#    writer  star  country    budget      gross  company  runtime  correct_year  \
# 0    2832   699       46  19000000   46998772     1426    146.0             0
# 1    1158   214       47   4500000   58853106      452    104.0             0
# 2    1818  1157       47  18000000  538375067      945    124.0             0
# 3    1413  1474       47   3500000   83453539     1108     88.0             0
# 4     351   271       47   6000000   39846344     1083     98.0             0
#
#    popularity
# 0           0
# 1           1
# 2           0
# 3           0
# 4           0

# %%
df_all_numerized = all_numerized.corr(method='spearman')
sns.heatmap(df_all_numerized, annot=True)
sns.set(rc={'figure.figsize':(20,15)})

# %%
#To check co-relation 1 by 1:
corr_matrix = all_numerized.corr()
corr_pairs = corr_matrix.unstack()
corr_pairs.head()
# Out:
# movie_name  movie_name    1.000000
#             rating       -0.029234
#             genre         0.010996
#             year          0.025542
#             released     -0.006152
# dtype: float64

# %%
#To check co-relation 1 by 1:
sorted_pairs = corr_pairs.sort_values(ascending=False)
sorted_pairs.head()
# Out:
# movie_name    movie_name      1.0
# rating        rating          1.0
# correct_year  correct_year    1.0
# runtime       runtime         1.0
# company       company         1.0
# dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs > .5) & (sorted_pairs != 1) ]
high_corr
# Out:
# year          correct_year    0.998726
# correct_year  year            0.998726
# budget        gross           0.740247
# gross         budget          0.740247
# votes         gross           0.614751
# gross         votes           0.614751
# dtype: float64

# %%
#Vote and budget have the highest correlation to gross earning
